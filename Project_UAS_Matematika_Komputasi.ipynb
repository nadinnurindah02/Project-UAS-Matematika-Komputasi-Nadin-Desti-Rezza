# %% [markdown]
# <a href="https://colab.research.google.com/github/nadinnurindah02/Project-UAS-Matematika-Komputasi-Nadin-Desti-Rezza/blob/main/Project_UAS_Matematika_Komputasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT UAS MATEMATIKA KOMPUTASI
#
# ## Aplikasi Metode Numerik Interaktif Berbasis Web untuk Menentukan Akar Persamaan Nonlinier
#
# Nama Kelompok:
#
# 1. Nadin Nur Indah
# 2. Destiana Lingga Sari
# 3. Rezza Ramadani
#
# Mata Kuliah: Matematika Komputasi
#
# # Tujuan Project
#
# Project ini dibuat untuk membantu mencari akar suatu persamaan nonlinier menggunakan metode numerik. Pada aplikasi ini pengguna dapat memasukkan fungsi yang ingin dicari akarnya, kemudian memilih metode yang ingin digunakan, yaitu Metode Bisection, Metode Newton-Raphson, atau Metode Secant.
#
# Program akan menghitung nilai akar persamaan, jumlah iterasi, menampilkan tabel proses perhitungan, serta grafik fungsi yang digunakan. Selain itu, hasil dari ketiga metode juga dapat dibandingkan untuk melihat perbedaan jumlah iterasi dan hasil yang diperoleh dari masing-masing metode.

# %% [markdown]
# # Metode Bisection
#
# Metode Bisection digunakan untuk mencari akar suatu persamaan dengan cara membagi interval menjadi dua bagian secara berulang.
#
# Metode ini memerlukan batas bawah dan batas atas yang memenuhi syarat bahwa nilai fungsi pada kedua batas tersebut memiliki tanda yang berbeda.
#
# Rumus yang digunakan pada Metode Bisection adalah:
#
# xt = (xa + xb) / 2
#
# Keterangan:
#
# xt = titik tengah interval
#
# xa = batas bawah
#
# xb = batas atas

# %%
# Import Library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Penjelasan Library
#
# NumPy digunakan untuk membantu perhitungan numerik.
#
# Pandas digunakan untuk membuat tabel hasil iterasi agar lebih mudah dibaca.
#
# Matplotlib digunakan untuk membuat grafik fungsi sehingga akar persamaan dapat dilihat secara visual.

# %%
# Input Data dari Pengguna
fungsi = input("Masukkan fungsi yang ingin dicari akarnya: ")

batas_bawah = float(input("Masukkan batas bawah interval: "))

batas_atas = float(input("Masukkan batas atas interval: "))

toleransi = float(input("Masukkan tingkat ketelitian yang diinginkan: "))
# Out:
# Masukkan fungsi yang ingin dicari akarnya: x**3-4*x-9
# Masukkan batas bawah interval: 2
# Masukkan batas atas interval: 3
# Masukkan tingkat ketelitian yang diinginkan: 0.0001

# %% [markdown]
# Penjelasan Input
#
# Fungsi adalah persamaan yang akan dicari akarnya.
#
# Batas bawah dan batas atas digunakan sebagai interval awal pencarian akar.
#
# Tingkat ketelitian (toleransi) digunakan untuk menentukan kapan proses iterasi dihentikan.
# Semakin kecil nilainya, semakin teliti hasil yang diperoleh.

# %%
# Membuat Fungsi Matematika
def hitung_fungsi(x):
    return eval(fungsi)

# %% [markdown]
# ## Penjelasan Fungsi
#
# Fungsi ini digunakan untuk menghitung nilai fungsi yang dimasukkan pengguna.
#
# Sebagai contoh, jika fungsi yang dimasukkan adalah x**3 - 4*x - 9, maka program dapat menghitung nilai fungsi tersebut pada setiap nilai x yang diperlukan.

# %%
# Memeriksa Syarat Metode Bisection
if hitung_fungsi(batas_bawah) * hitung_fungsi(batas_atas) > 0:
    print("Interval yang dimasukkan tidak memenuhi syarat Metode Bisection")
else:
    print("Interval memenuhi syarat")
# Out:
# Interval memenuhi syarat

# %% [markdown]
# ## Validasi Interval
#
# Metode Bisection mensyaratkan bahwa fungsi pada batas bawah dan batas atas memiliki tanda yang berbeda.
#
# Jika syarat ini tidak terpenuhi, maka proses pencarian akar tidak dapat dilakukan.

# %%
# Perhitungan Metode Bisection

data_iterasi = []

jumlah_iterasi = 0

while abs(batas_atas - batas_bawah) > toleransi:

    titik_tengah = (batas_bawah + batas_atas) / 2

    data_iterasi.append([
        jumlah_iterasi + 1,
        batas_bawah,
        batas_atas,
        titik_tengah
    ])

    if hitung_fungsi(batas_bawah) * hitung_fungsi(titik_tengah) < 0:
        batas_atas = titik_tengah
    else:
        batas_bawah = titik_tengah

    jumlah_iterasi += 1

akar = (batas_bawah + batas_atas) / 2

print("Akar persamaan =", akar)

print("Jumlah iterasi =", jumlah_iterasi)
# Out:
# Akar persamaan = 2.706512451171875
# Jumlah iterasi = 14

# %% [markdown]
# ## Melakukan Perhitungan Metode Bisection
#
# Pada bagian ini program melakukan proses pencarian akar secara berulang sampai diperoleh hasil yang memenuhi tingkat ketelitian yang diinginkan.

# %%
# Menampilkan Tabel Iterasi

tabel_iterasi = pd.DataFrame(
    data_iterasi,
    columns=[
        "Iterasi",
        "Batas Bawah",
        "Batas Atas",
        "Titik Tengah"
    ]
)

tabel_iterasi
# Out:
#     Iterasi  Batas Bawah  Batas Atas  Titik Tengah
# 0         1     2.000000    3.000000      2.500000
# 1         2     2.500000    3.000000      2.750000
# 2         3     2.500000    2.750000      2.625000
# 3         4     2.625000    2.750000      2.687500
# 4         5     2.687500    2.750000      2.718750
# 5         6     2.687500    2.718750      2.703125
# 6         7     2.703125    2.718750      2.710938
# 7         8     2.703125    2.710938      2.707031
# 8         9     2.703125    2.707031      2.705078
# 9        10     2.705078    2.707031      2.706055
# 10       11     2.706055    2.707031      2.706543
# 11       12     2.706055    2.706543      2.706299
# 12       13     2.706299    2.706543      2.706421
# 13       14     2.706421    2.706543      2.706482

# %%
# Menampilkan Grafik Fungsi

x = np.linspace(batas_bawah - 2, batas_atas + 2, 400)
y = [hitung_fungsi(nilai_x) for nilai_x in x]

plt.figure(figsize=(8,5))
plt.plot(x, y)
plt.axhline(y=0)

plt.title("Grafik Fungsi")
plt.xlabel("Nilai x")
plt.ylabel("Nilai f(x)")
plt.grid()
plt.show()

# %% [markdown]
# ## Penjelasan Grafik Fungsi
# Berdasarkan hasil perhitungan, Metode Bisection berhasil menentukan akar persamaan nonlinier sesuai tingkat ketelitian yang diberikan.
#
# Program juga menampilkan tabel iterasi dan grafik fungsi sehingga proses pencarian akar dapat diamati dengan lebih mudah.

# %%
# Menyimpan Hasil Bisection

hasil_akar_bisection = akar

hasil_iterasi_bisection = jumlah_iterasi

# %% [markdown]
# # Metode Newton-Raphson
#
# Metode Newton-Raphson digunakan untuk mencari akar suatu persamaan menggunakan pendekatan garis singgung.
#
# Metode ini memerlukan fungsi dan turunan fungsi untuk memperoleh pendekatan akar yang baru pada setiap iterasi.
#
# Rumus yang digunakan pada Metode Newton-Raphson adalah:
#
# x_(n+1) = x_n - f(x_n) / f'(x_n)
#
# Keterangan:
#
# x_(n+1) = pendekatan akar yang baru
#
# x_n = pendekatan akar sebelumnya
#
# f(x_n) = nilai fungsi pada x_n
#
# f'(x_n) = nilai turunan fungsi pada x_n

# %%
# Import Library Tambahan

import sympy as sp

# %% [markdown]
# Library SymPy digunakan untuk menghitung turunan fungsi secara otomatis sehingga pengguna tidak perlu mencari turunannya secara manual.

# %%
# Input Data dari Pengguna

fungsi = input("Masukkan fungsi yang ingin dicari akarnya: ")

tebakan_awal = float(input("Masukkan tebakan awal: "))

toleransi = float(input("Masukkan tingkat ketelitian yang diinginkan: "))
# Out:
# Masukkan fungsi yang ingin dicari akarnya: x**3-4*x-9
# Masukkan tebakan awal: 3
# Masukkan tingkat ketelitian yang diinginkan: 0.0001

# %% [markdown]
# # Penjelasan Input Data
#
# Pada bagian ini pengguna diminta memasukkan fungsi yang akan dicari akarnya, nilai tebakan awal, dan nilai toleransi yang digunakan sebagai batas ketelitian hasil.

# %%
# Membuat Fungsi dan Turunan Fungsi

x = sp.Symbol("x")

fungsi_sympy = sp.sympify(fungsi)

turunan_fungsi = sp.diff(fungsi_sympy, x)

print("Turunan fungsi =", turunan_fungsi)
# Out:
# Turunan fungsi = 3*x**2 - 4

# %% [markdown]
# # Penjelasan Input
# Pada bagian ini program mengubah fungsi yang dimasukkan pengguna menjadi bentuk matematika yang dapat dihitung oleh Python.
#
# Program juga menghitung turunan fungsi yang akan digunakan pada Metode Newton-Raphson.

# %%
# Perhitungan Metode Newton-Raphson

data_iterasi = []

akar = tebakan_awal

jumlah_iterasi = 0

while True:

    nilai_fungsi = float(fungsi_sympy.subs(x, akar))

    nilai_turunan = float(turunan_fungsi.subs(x, akar))

    akar_baru = akar - (nilai_fungsi / nilai_turunan)

    data_iterasi.append([
        jumlah_iterasi + 1,
        akar,
        akar_baru
    ])

    if abs(akar_baru - akar) < toleransi:
        break

    akar = akar_baru

    jumlah_iterasi += 1

print("Akar persamaan =", akar_baru)

print("Jumlah iterasi =", jumlah_iterasi)
# Out:
# Akar persamaan = 2.7065279544979393
# Jumlah iterasi = 3

# %% [markdown]
# # Penjelasan Perhitungan
#
# Pada bagian ini program melakukan proses pencarian akar persamaan menggunakan Metode Newton-Raphson. Nilai pendekatan akar akan terus diperbarui sampai hasil yang diperoleh memenuhi tingkat ketelitian yang telah ditentukan.

# %%
# Menampilkan Tabel Iterasi

tabel_iterasi = pd.DataFrame(
    data_iterasi,
    columns=[
        "Iterasi",
        "x lama",
        "x baru"
    ]
)

tabel_iterasi
# Out:
#    Iterasi    x lama    x baru
# 0        1  3.000000  2.739130
# 1        2  2.739130  2.706998
# 2        3  2.706998  2.706528
# 3        4  2.706528  2.706528

# %% [markdown]
# # Penjelasan Tabel Iterasi
#
# Tabel ini digunakan untuk melihat perkembangan nilai pendekatan akar pada setiap iterasi sampai diperoleh hasil akhir yang diinginkan.

# %%
# Menampilkan Grafik Fungsi

fungsi_numerik = sp.lambdify(x, fungsi_sympy)

nilai_x = np.linspace(
    akar_baru - 5,
    akar_baru + 5,
    400
)

nilai_y = fungsi_numerik(nilai_x)

plt.figure(figsize=(8,5))

plt.plot(nilai_x, nilai_y)

plt.axhline(y=0)

plt.title("Grafik Fungsi")

plt.xlabel("Nilai x")

plt.ylabel("Nilai f(x)")

plt.grid()

plt.show()

# %% [markdown]
# # Penjelasan Grafik Fungsi
#
# Grafik ditampilkan untuk membantu melihat bentuk fungsi yang digunakan dan menunjukkan posisi akar persamaan yang diperoleh dari hasil perhitungan.

# %%
# Menyimpan Hasil Newton-Raphson

hasil_akar_newton = akar_baru

hasil_iterasi_newton = jumlah_iterasi

# %% [markdown]
# # Metode Secant
#
# Metode Secant digunakan untuk mencari akar suatu persamaan menggunakan dua tebakan awal. Metode ini tidak memerlukan turunan fungsi sehingga lebih sederhana dibandingkan Metode Newton-Raphson.
#
# Rumus yang digunakan pada Metode Secant adalah:
#
# x_(n+1) = x_n - [f(x_n)(x_n - x_(n-1))] / [f(x_n) - f(x_(n-1))]
#
# Keterangan:
#
# x_(n+1) = nilai pendekatan akar yang baru
#
# x_n = nilai pendekatan akar saat ini
#
# x_(n-1) = nilai pendekatan akar sebelumnya
#
# f(x_n) = nilai fungsi pada x_n
#
# f(x_(n-1)) = nilai fungsi pada x_(n-1)

# %%
\# Input Data dari Pengguna

fungsi = input("Masukkan fungsi yang ingin dicari akarnya: ")

tebakan_pertama = float(input("Masukkan tebakan pertama: "))

tebakan_kedua = float(input("Masukkan tebakan kedua: "))

toleransi = float(input("Masukkan tingkat ketelitian yang diinginkan: "))
# Out:
# Masukkan fungsi yang ingin dicari akarnya: x**3-4*x-9
# Masukkan tebakan pertama: 2
# Masukkan tebakan kedua: 3
# Masukkan tingkat ketelitian yang diinginkan: 0.0001

# %% [markdown]
# # Penjelasan Input Data
#
# Pada bagian ini pengguna diminta memasukkan fungsi yang akan dicari akarnya, dua tebakan awal, dan nilai toleransi sebagai batas ketelitian hasil yang diinginkan.

# %%
# Membuat Fungsi Matematika
def hitung_fungsi(x):
    return eval(fungsi)

# %% [markdown]
# # Penjelasan Fungsi Matematika
#
# Bagian ini digunakan agar fungsi yang dimasukkan pengguna dapat dibaca dan dihitung oleh program. Fungsi tersebut nantinya akan digunakan pada setiap proses iterasi.

# %%
# Perhitungan Metode Secant
data_iterasi = []

jumlah_iterasi = 0

while True:

    nilai_x0 = hitung_fungsi(tebakan_pertama)

    nilai_x1 = hitung_fungsi(tebakan_kedua)

    akar_baru = tebakan_kedua - (
        nilai_x1 * (tebakan_kedua - tebakan_pertama)
    ) / (nilai_x1 - nilai_x0)

    data_iterasi.append([
        jumlah_iterasi + 1,
        tebakan_pertama,
        tebakan_kedua,
        akar_baru
    ])

    if abs(akar_baru - tebakan_kedua) < toleransi:
        break

    tebakan_pertama = tebakan_kedua
    tebakan_kedua = akar_baru

    jumlah_iterasi += 1

print("Akar persamaan =", akar_baru)

print("Jumlah iterasi =", jumlah_iterasi)
# Out:
# Akar persamaan = 2.706527953295662
# Jumlah iterasi = 4

# %% [markdown]
# # Penjelasan Perhitungan
#
# Pada bagian ini program melakukan perhitungan Metode Secant secara berulang. Iterasi akan berhenti ketika hasil yang diperoleh sudah memenuhi nilai toleransi yang ditentukan.

# %%
# Menampilkan Tabel Iterasi

tabel_iterasi = pd.DataFrame(
    data_iterasi,
    columns=[
        "Iterasi",
        "Tebakan Pertama",
        "Tebakan Kedua",
        "Akar Baru"
    ]
)

tabel_iterasi
# Out:
#    Iterasi  Tebakan Pertama  Tebakan Kedua  Akar Baru
# 0        1         2.000000       3.000000   2.600000
# 1        2         3.000000       2.600000   2.693252
# 2        3         2.600000       2.693252   2.707193
# 3        4         2.693252       2.707193   2.706524
# 4        5         2.707193       2.706524   2.706528

# %% [markdown]
# # Penjelasan Tabel Iterasi
#
# Tabel ini digunakan untuk melihat perkembangan hasil pada setiap iterasi sampai diperoleh nilai akar persamaan yang diinginkan.

# %%
# Menampilkan Grafik Fungsi

nilai_x = np.linspace(
    akar_baru - 5,
    akar_baru + 5,
    400
)

nilai_y = [hitung_fungsi(x) for x in nilai_x]

plt.figure(figsize=(8,5))

plt.plot(nilai_x, nilai_y)

plt.axhline(y=0)

plt.title("Grafik Fungsi")

plt.xlabel("Nilai x")

plt.ylabel("Nilai f(x)")

plt.grid()

plt.show()

# %% [markdown]
# # Penjelasan Grafik Fungsi
#
# Grafik ditampilkan untuk membantu melihat bentuk fungsi yang digunakan dan memperlihatkan posisi akar persamaan yang diperoleh.

# %%
# Menyimpan Hasil Secant

hasil_akar_secant = akar_baru

hasil_iterasi_secant = jumlah_iterasi

# %% [markdown]
# # Perbandingan Ketiga Metode
#
# Pada bagian ini dilakukan perbandingan hasil dari Metode Bisection, Metode Newton-Raphson, dan Metode Secant.
#
# Perbandingan dilakukan berdasarkan nilai akar yang diperoleh dan jumlah iterasi yang dibutuhkan untuk mencapai tingkat ketelitian yang sama.

# %%
# Membuat Tabel Perbandingan

tabel_perbandingan = pd.DataFrame({

    "Metode": [
        "Bisection",
        "Newton-Raphson",
        "Secant"
    ],

    "Akar Persamaan": [
        hasil_akar_bisection,
        hasil_akar_newton,
        hasil_akar_secant
    ],

    "Jumlah Iterasi": [
        hasil_iterasi_bisection,
        hasil_iterasi_newton,
        hasil_iterasi_secant
    ]

})

tabel_perbandingan
# Out:
#            Metode  Akar Persamaan  Jumlah Iterasi
# 0       Bisection        2.706512              14
# 1  Newton-Raphson        2.706528               3
# 2          Secant        2.706528               4

# %% [markdown]
# # Penjelasan Tabel Perbandingan
#
# Berdasarkan tabel perbandingan, ketiga metode berhasil menemukan akar dari persamaan yang sama.
#
# Metode Newton-Raphson dan Metode Secant menghasilkan nilai akar yang sama, sedangkan Metode Bisection menghasilkan nilai akar yang sangat dekat dengan kedua metode tersebut. Perbedaan kecil yang muncul disebabkan oleh proses pendekatan dan tingkat ketelitian yang digunakan pada setiap metode.
#
# Dari segi jumlah iterasi, Metode Newton-Raphson membutuhkan 3 iterasi, Metode Secant membutuhkan 4 iterasi, sedangkan Metode Bisection membutuhkan 14 iterasi. Hal ini menunjukkan bahwa Metode Newton-Raphson dan Metode Secant dapat menemukan akar persamaan lebih cepat dibandingkan Metode Bisection.

# %%
# Menampilkan Grafik Perbandingan Jumlah Iterasi

metode = [
    "Bisection",
    "Newton-Raphson",
    "Secant"
]

jumlah_iterasi = [
    hasil_iterasi_bisection,
    hasil_iterasi_newton,
    hasil_iterasi_secant
]

plt.figure(figsize=(8,5))

plt.bar(metode, jumlah_iterasi)

plt.title("Perbandingan Jumlah Iterasi")

plt.xlabel("Metode")

plt.ylabel("Jumlah Iterasi")

plt.grid()

plt.show()

# %% [markdown]
# # Penjelasan Grafik Perbandingan
#
# Berdasarkan grafik yang diperoleh, Metode Bisection membutuhkan jumlah iterasi paling banyak, yaitu 14 iterasi. Metode Newton-Raphson membutuhkan 3 iterasi, sedangkan Metode Secant membutuhkan 4 iterasi.
#
# Hal ini menunjukkan bahwa Metode Newton-Raphson dan Metode Secant dapat mencapai hasil yang diinginkan lebih cepat dibandingkan Metode Bisection. Pada kasus ini, Metode Newton-Raphson merupakan metode yang paling efisien karena memerlukan jumlah iterasi paling sedikit.

# %% [markdown]
# # Kesimpulan Project
#
# Berdasarkan hasil yang diperoleh, Metode Bisection, Metode Newton-Raphson, dan Metode Secant berhasil digunakan untuk mencari akar persamaan nonlinier.
#
# Ketiga metode menghasilkan nilai akar yang hampir sama, sehingga dapat dikatakan bahwa ketiga metode tersebut mampu menemukan solusi dari persamaan yang diberikan. Namun, jumlah iterasi yang dibutuhkan oleh setiap metode berbeda-beda.
#
# Pada project ini, Metode Newton-Raphson membutuhkan 3 iterasi, Metode Secant membutuhkan 4 iterasi, sedangkan Metode Bisection membutuhkan 14 iterasi. Hal ini menunjukkan bahwa Metode Newton-Raphson merupakan metode yang paling cepat untuk kasus yang digunakan pada project ini.
#
# Melalui project ini dapat dipahami bahwa setiap metode memiliki cara kerja yang berbeda, tetapi tetap dapat menghasilkan solusi yang sama. Selain itu, penggunaan tabel iterasi dan grafik fungsi membantu pengguna untuk melihat proses pencarian akar persamaan dengan lebih jelas.
